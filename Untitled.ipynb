# %%
from bar_cnn.models.backbones import resnet

# %%
model = resnet.ResNet(auto_model_build=False)
# Out:
# MODEL IS PARTIALLY BUILT ...
# PLEASE RUN THE FOLLOWING BUILD STEPS:...
# 	1. <model_instance>.build_architecture()	2. <model_instance>.define_loss_fns()
# 	3. <model_instance>.define_loss_wts()
# 	4. <model_instance>.define_optimizer()
# 	5. <model_instance>.define_output_path()
# 	6. <model_instance>.define_callbacks()
# 	7. <model_instance>.define_class_wts()
#
# WHEN YOU ARE FINISHED ...
# YOU WILL BE ABLE TO MANUALLY RUN ...
# 	<model_instance>.compile_model() AND <model_instance>.fit_model(tf_dataset)

# %%
model.model = model.build_architecture()

# %%
model.model.summary()
# Out:
# Model: "resnet-bar-cnn"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 160, 160, 3) 0
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 80, 80, 64)   9408        input_1[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 80, 80, 64)   256         conv1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 80, 80, 64)   0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 82, 82, 64)   0           activation[0][0]
# ...
